# %%
# !pip install kaggle
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !kaggle datasets list -s "goal leagues"
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np

# %%
path = "epl-goalScorer(20-21).csv"
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0    id             player_name  games  time  goals        xG  \
# 517         517  9415  Jaden Philogene-Bidace      1     1      0  0.000000
# 518         518  9423         Gaetano Berardi      2   113      0  0.074761
# 519         519  9524          Anthony Elanga      1    67      0  0.000000
# 520         520  9540             Femi Seriki      1     1      0  0.000000
# 521         521  9552         Tyrese Francois      1    13      0  0.000000
#
#      assists   xA  shots  key_passes  yellow_cards  red_cards position  \
# 517        0  0.0      0           0             0          0        S
# 518        0  0.0      1           0             0          0      D S
# 519        0  0.0      0           0             0          0        M
# 520        0  0.0      0           0             0          0        S
# 521        0  0.0      0           0             0          0        S
#
#             team_title  npg      npxG   xGChain  xGBuildup
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
len(df.dtypes)
# Out:
# 19

# %%
df
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
df_tanpaid = df.iloc[:,3:]
df_tanpaid
# Out:
#      games  time  goals         xG  assists         xA  shots  key_passes  \
# 0       35  3097     23  22.174859       14   7.577094    138          49
# 1       37  3085     22  20.250847        5   6.528526    126          55
# 2       37  3117     18  16.019454       12  11.474996    121          95
# 3       37  3139     17  11.023287       10   9.512992     68          75
# 4       38  3085     17  18.401863        7   3.782247    107          30
# ..     ...   ...    ...        ...      ...        ...    ...         ...
# 517      1     1      0   0.000000        0   0.000000      0           0
# 518      2   113      0   0.074761        0   0.000000      1           0
# 519      1    67      0   0.000000        0   0.000000      0           0
# 520      1     1      0   0.000000        0   0.000000      0           0
# 521      1    13      0   0.000000        0   0.000000      0           0
#
#      yellow_cards  red_cards position         team_title  npg       npxG  \
# ...

# %%
df_tanpaid = df.iloc[:,2:]
df_tanpaid
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# ...

# %%
df
# Out:
#      Unnamed: 0    id             player_name  games  time  goals         xG  \
# 0             0   647              Harry Kane     35  3097     23  22.174859
# 1             1  1250           Mohamed Salah     37  3085     22  20.250847
# 2             2  1228         Bruno Fernandes     37  3117     18  16.019454
# 3             3   453           Son Heung-Min     37  3139     17  11.023287
# 4             4   822         Patrick Bamford     38  3085     17  18.401863
# ..          ...   ...                     ...    ...   ...    ...        ...
# 517         517  9415  Jaden Philogene-Bidace      1     1      0   0.000000
# 518         518  9423         Gaetano Berardi      2   113      0   0.074761
# 519         519  9524          Anthony Elanga      1    67      0   0.000000
# 520         520  9540             Femi Seriki      1     1      0   0.000000
# 521         521  9552         Tyrese Francois      1    13      0   0.000000
#
# ...

# %%
df_rapi = df_tanpaid.sort_values(by="player_name", ascending=True)
df_rapi.head(15)
# Out:
#                 player_name  games  time  goals        xG  assists        xA  \
# 154          Aaron Connolly     16   755      2  4.412464        1  0.149897
# 281         Aaron Cresswell     35  3086      0  0.883464        8  7.347331
# 390          Aaron Ramsdale     37  3330      0  0.000000        0  0.053571
# 139       Aaron Wan-Bissaka     34  3060      2  0.932454        4  2.547663
# 126      Abdoulaye Doucouré     28  2409      2  2.369523        3  2.381616
# 380        Aboubakar Kamara     11   303      0  0.654920        0  0.328969
# 163            Adam Lallana     29  1528      1  1.614306        1  2.628758
# 242            Adam Webster     28  2506      1  1.272957        0  0.253216
# 119            Adama Traoré     36  2604      2  1.995262        2  5.228081
# 75          Ademola Lookman     34  2765      4  6.251116        4  5.258407
# 278                  Adrián      3   270      0  0.000000        0  0.000000
# ...

# %%
df_rapi = df_tanpaid.sort_values(by="assists", ascending=False)
df_rapi.head(15)
# Out:
#            player_name  games  time  goals         xG  assists         xA  \
# 0           Harry Kane     35  3097     23  22.174859       14   7.577094
# 2      Bruno Fernandes     37  3117     18  16.019454       12  11.474996
# 58     Kevin De Bruyne     24  1918      5   9.908440       11  10.003763
# 3        Son Heung-Min     37  3139     17  11.023287       10   9.512992
# 51       Jack Grealish     26  2187      6   5.192684       10   9.334137
# 15     Marcus Rashford     37  2941     11   9.579710        9   4.185122
# 6          Jamie Vardy     34  2848     15  19.942946        9   5.087882
# 57            Raphinha     30  2369      6   6.219143        9   9.524861
# 49         Timo Werner     35  2605      6  13.432796        8   6.667277
# 281    Aaron Cresswell     35  3086      0   0.883464        8   7.347331
# 83         Pascal Groß     33  2379      3   5.010526        8   5.368290
# 41       Jack Harrison     36  2871      8   6.254043        8   7.523059
# ...

# %%
df_rapi.describe()
# Out:
#             games         time       goals          xG     assists  \
# count  522.000000   522.000000  522.000000  522.000000  522.000000
# mean    19.643678  1420.068966    1.862069    2.000806    1.289272
# std     11.619836  1031.604819    3.338851    3.317946    2.083350
# min      1.000000     1.000000    0.000000    0.000000    0.000000
# 25%     10.000000   470.250000    0.000000    0.074668    0.000000
# 50%     21.000000  1342.000000    1.000000    0.737295    0.000000
# 75%     30.000000  2319.000000    2.000000    2.053378    2.000000
# max     38.000000  3420.000000   23.000000   22.174859   14.000000
#
#                xA       shots  key_passes  yellow_cards   red_cards  \
# count  522.000000  522.000000  522.000000    522.000000  522.000000
# mean     1.376029   17.379310   12.963602      2.061303    0.091954
# std      1.886510   21.572664   16.164361      2.203661    0.295800
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# ...

# %%
df_rapi.describe(include='all')
# Out:
#        player_name       games         time       goals          xG  \
# count          522  522.000000   522.000000  522.000000  522.000000
# unique         522         NaN          NaN         NaN         NaN
# top     Harry Kane         NaN          NaN         NaN         NaN
# freq             1         NaN          NaN         NaN         NaN
# mean           NaN   19.643678  1420.068966    1.862069    2.000806
# std            NaN   11.619836  1031.604819    3.338851    3.317946
# min            NaN    1.000000     1.000000    0.000000    0.000000
# 25%            NaN   10.000000   470.250000    0.000000    0.074668
# 50%            NaN   21.000000  1342.000000    1.000000    0.737295
# 75%            NaN   30.000000  2319.000000    2.000000    2.053378
# max            NaN   38.000000  3420.000000   23.000000   22.174859
#
#            assists          xA       shots  key_passes  yellow_cards  \
# count   522.000000  522.000000  522.000000  522.000000    522.000000
# ...

# %%
df_tanpaid.describe(include='all')
# Out:
#        player_name       games         time       goals          xG  \
# count          522  522.000000   522.000000  522.000000  522.000000
# unique         522         NaN          NaN         NaN         NaN
# top     Harry Kane         NaN          NaN         NaN         NaN
# freq             1         NaN          NaN         NaN         NaN
# mean           NaN   19.643678  1420.068966    1.862069    2.000806
# std            NaN   11.619836  1031.604819    3.338851    3.317946
# min            NaN    1.000000     1.000000    0.000000    0.000000
# 25%            NaN   10.000000   470.250000    0.000000    0.074668
# 50%            NaN   21.000000  1342.000000    1.000000    0.737295
# 75%            NaN   30.000000  2319.000000    2.000000    2.053378
# max            NaN   38.000000  3420.000000   23.000000   22.174859
#
#            assists          xA       shots  key_passes  yellow_cards  \
# count   522.000000  522.000000  522.000000  522.000000    522.000000
# ...

# %%
df_rapi = df_tanpaid.sort_values(by="games", ascending=False)
df_rapi.head(15)
# Out:
#                player_name  games  time  goals         xG  assists        xA  \
# 204       Andrew Robertson     38  3391      1   1.437934        7  7.220492
# 480            Luke Ayling     38  3400      0   1.439750        0  2.988854
# 327           Matt Targett     38  3407      0   0.280304        2  2.799669
# 116    Georginio Wijnaldum     38  2961      2   2.817427        0  1.662922
# 4          Patrick Bamford     38  3085     17  18.401863        7  3.782247
# 311      Kasper Schmeichel     38  3420      0   0.000000        0  0.000000
# 55         Youri Tielemans     38  3359      6   4.168204        4  3.312251
# 40           Stuart Dallas     38  3412      8   4.457074        2  2.084683
# 296            Hugo Lloris     38  3420      0   0.000000        0  0.000000
# 378      Emiliano Martinez     38  3420      0   0.000000        0  0.122923
# 110  Pierre-Emile Højbjerg     38  3420      2   1.137927        4  1.755895
# ...

# %%
df_rapi[['goals', 'games', 'assists', 'shots']].mean()
# Out:
# goals       1.862069
# games      19.643678
# assists     1.289272
# shots      17.379310
# dtype: float64

# %%
df_rapi[['goals', 'games', 'assists', 'shots']].median()
# Out:
# goals       1.0
# games      21.0
# assists     0.0
# shots      10.0
# dtype: float64

# %%
df_rapi[['goals', 'games', 'assists', 'shots']].mode()
# Out:
#    goals  games  assists  shots
# 0      0      1        0      0

# %%
df_rapi[['team_title']].mode()
# Out:
#              team_title
# 0               Everton
# 1  West Bromwich Albion

# %%
df_rapi = df_tanpaid.sort_values(by="team_title", ascending=True)
df_rapi.tail(70)
# Out:
#          player_name  games  time  goals        xG  assists        xA  shots  \
# 485     Kyle Edwards      5   110      0  0.118816        0  0.021379      2
# 240     Karlan Grant     21  1140      1  1.694241        0  0.149186     16
# 157  Conor Gallagher     30  2529      2  1.542326        2  1.418288     29
# 372   Kamil Grosicki      3   151      0  0.109249        1  0.566356      3
# 490   Conor Townsend     25  2237      0  0.822823        2  2.648507     11
# ..               ...    ...   ...    ...       ...      ...       ...    ...
# 391  Fernando Marçal     12   609      0  0.074555        0  0.127292      2
# 381  Patrick Cutrone      2    21      0  0.071458        0  0.000000      1
# 80       Fabio Silva     31  1251      4  5.958539        2  1.035431     45
# 502    Theo Corbeanu      1     7      0  0.000000        0  0.023470      0
# 231       Willy Boly     20  1790      1  1.117670        1  0.551295     14
#
# ...
